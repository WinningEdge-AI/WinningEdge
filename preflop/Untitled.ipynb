# %%
import pandas as pd

# %%
df = pd.read_csv("../dataframe/poker_dataframe.csv")
filtered_df = df[df['SB cards'].notna()]

# %%
filtered_df=filtered_df.reset_index(drop=True)
filtered_df
# Out:
#          Game ID                                               File  \
# 0      603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1      603607691  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2      603607964  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3      603607982  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4      502906150  Bayamo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...          ...                                                ...
# 86063  553224321  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 86064  553224342  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 86065  553224357  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 86066  553224367  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 86067  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB     Player BB  \
# 0        ArcticWin        Ceaban
# 1       grandiozzo     MARUSYA94
# 2       grandiozzo   gunchozaurs
# ...

# %%
def suited_hole_cards(cards):
    """
    This function returns true if hole cards are suited
    """
    if len(cards)!=10:
        raise ValueError("String must contain 10 characters!")
        
    return cards[3]==cards[7]

# %%
def hole_cards_3_letter_style(cards):
    """
    This function takes the hole cards and translates them to the 3 letter style.
    The output is ordered to show the highest card first
    
    Ex: [ Qh, Tc ]-> QTo because the suits are different
    """
    if len(cards)!=10:
        raise ValueError("String must contain 10 characters!")   
        
    rank_values = {'A': 14, 'K': 13, 'Q': 12, 'J': 11, 'T': 10, '9': 9, '8': 8, '7': 7, '6': 6, '5': 5, '4': 4, '3': 3, '2': 2}
    
    sorted_cards = sorted([cards[2],cards[6]], key=lambda x: rank_values.get(x[0], 0), reverse=True)
    
    if suited_hole_cards(cards):
        return sorted_cards[0] + sorted_cards[1] + 's'
    else:
        return sorted_cards[0] + sorted_cards[1] + 'o'

# %%
filtered_df['SB cards 3style'] = filtered_df['SB cards'].apply(hole_cards_3_letter_style)
filtered_df['BB cards 3style'] = filtered_df['BB cards'].apply(hole_cards_3_letter_style)

# Show the DataFrame with the new column
filtered_df.head()  # .head() just shows the first few rows
# Out:
#      Game ID                                               File     Player SB  \
# 0  603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...    ArcticWin
# 1  603607691  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...   grandiozzo
# 2  603607964  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...   grandiozzo
# 3  603607982  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...  gunchozaurs
# 4  502906150  Bayamo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...   JillybeanG
#
#       Player BB                                    Preflop actions  \
# 0       Ceaban                           [('c', '0.01'), ('k', 0)]
# 1    MARUSYA94                           [('c', '0.01'), ('k', 0)]
# 2  gunchozaurs                           [('c', '0.01'), ('k', 0)]
# 3   grandiozzo                      [('r', '0.03'), ('c', '0.02')]
# 4        Dbloy   [('r', '0.03'), ('r', '0.10'), ('r', '0.16'), ...
#
#            Flop actions          Turn actions                   River actions  \
# ...

# %%
import pandas as pd

# Sample data: a list of lists with tuples for cell name and value
# Replace this with your actual data
sample_data = [[(f'Name{i}{j}', i*j) for j in range(1, 14)] for i in range(1, 14)]

# Create a pandas DataFrame
df = pd.DataFrame(sample_data)

# Function to display the DataFrame in a 13x13 format with cell names and values
def display_table(data_frame):
    # Creating a displayable table with both name and value
    display_data = pd.DataFrame(index=data_frame.index, columns=data_frame.columns)

    for row in data_frame.iterrows():
        row_index = row[0]
        for col_index in range(len(row[1])):
            cell = row[1][col_index]
            display_data.iloc[row_index, col_index] = f"{cell[0]}: {cell[1]}"

    return display_data

# Display the table
display_table(df)

# %%
filtered_df.to_csv('preflop_df.csv', index=False)  # Set index=False to exclude the index column

# %%
# Use value_counts() to count unique values in the 'Category' column
value_counts = filtered_df['BB cards 3style'].value_counts()

# Display the counts
print(value_counts)
# Out:
# BB cards 3style
# JTo    1008
# A8o    1003
# KJo     977
# QJo     975
# ATo     973
# A7o     969
# A9o     967
# AQo     966
# QTo     961
# A5o     960
# KQo     940
# T9o     919
# KTo     918
# AJo     906
# AKo     902
# K9o     892
# A6o     891
# K8o     890
# A2o     886
# Q9o     884
# 98o     875
# A3o     873
# A4o     873
# K7o     822
# 87o     818
# J9o     818
# 76o     815
# J8o     795
# Q8o     786
# T8o     779
# J7o     775
# K6o     766
# Q7o     765
# 97o     764
# Q5o     740
# Q6o     739
# 65o     733
# K5o     705
# 86o     690
# T7o     687
# K4o     683
# K2o     681
# K3o     668
# 54o     668
# 75o     659
# Q4o     658
# 85o     656
# 96o     643
# J6o     642
# T6o     642
# 43o     636
# J4o     625
# 84o     617
# 64o     615
# 74o     614
# 94o     611
# J5o     605
# 53o     602
# Q2o     599
# T5o     596
# J3o     587
# Q3o     584
# J2o     583
# T4o     580
# 63o     577
# 62o     572
# 42o     568
# 77o     568
# T2o     566
# 83o     564
# ...

# %%
pd.set_option('display.max_rows', None)

filtered_df.head(100)

# %%
# Assuming df is your DataFrame
filtered_rows = filtered_df[filtered_df['BB cards 3style'] == 'hho']

# Print all rows where 'SB cards 3style' is 'hho'
print(filtered_rows)
# Out:
#          Game ID                                               File Player SB  \
# 48034  515261185  Harare-0.01-0.02-USD-NoLimitHoldem-Pacific-11-...  NMelisa
# 48036  515261281  Harare-0.01-0.02-USD-NoLimitHoldem-Pacific-11-...  NMelisa
# 48038  515261394  Harare-0.01-0.02-USD-NoLimitHoldem-Pacific-11-...  NMelisa
#
#          Player BB            Preflop actions               Flop actions  \
# 48034  chrishowse                  [('f', 0)]                        NaN
# 48036  chrishowse   [('c', '0.01'), ('k', 0)]  [('b', '0.04'), ('f', 0)]
# 48038  chrishowse                  [('f', 0)]                        NaN
#
#       Turn actions River actions                Flop Turn River  SB stack  \
# 48034          NaN           NaN                 NaN  NaN   NaN      1.87
# 48036          NaN           NaN  ['Kh', '3c', 'Jc']  NaN   NaN      1.90
# 48038          NaN           NaN                 NaN  NaN   NaN      1.68
#
# ...

# %%
desired_index = 48035    # Replace with the index of the row you want to print
row_to_print = filtered_df.loc[desired_index]

# Print the row with the specified index
print(row_to_print[1])
# Out:
# Harare-0.01-0.02-USD-NoLimitHoldem-Pacific-11-5-2018.txt
# /tmp/ipykernel_92/3119162547.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(row_to_print[1])

# %%
bugged rows:
    48034, 48035, 48036, 48038

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
