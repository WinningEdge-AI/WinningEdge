# %%
import pandas as pd

# %%
df = pd.read_pickle("../dataframe/poker_dataframe.pkl")
df
# Out:
#           Game ID                                               File  \
# 0       502874582  Arezzo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1       603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2       603604231  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3       603604236  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4       603604241  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...           ...                                                ...
# 520806  553224385  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520807  553224389  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520808  553224821  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520809  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520810  553224845  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB      Player BB         Preflop actions  \
# 0         Oracool1   sirstadiljus                 [(f, 0)]
# 1        ArcticWin         Ceaban      [(c, 0.01), (k, 0)]
# 2           Ceaban      ArcticWin                 [(f, 0)]
# 3        ArcticWin         Ceaban                 [(f, 0)]
# 4           Ceaban      ArcticWin                 [(f, 0)]
# ...             ...            ...                     ...
# 520806  Sensei.Dbb        roghnov      [(c, 0.01), (k, 0)]
# 520807     roghnov     Sensei.Dbb      [(r, 0.03), (f, 0)]
# 520808     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
# 520809  John_Efapi        mikvell   [(r, 0.05), (c, 0.04)]
# 520810     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
#
#                        Flop actions                 Turn actions  \
# 0                              None                         None
# 1                  [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 2                              None                         None
# 3                              None                         None
# 4                              None                         None
# ...                             ...                          ...
# 520806  [(k, 0), (b, 0.02), (f, 0)]                         None
# 520807                         None                         None
# 520808       [(b, 0.04), (c, 0.04)]  [(k, 0), (b, 0.08), (f, 0)]
# 520809             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 520810             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
#
#                  River actions          Flop  Turn River SB stack BB stack  \
# 0                         None          None  None  None     1.22     2.01
# 1       [(b, 0.04), (c, 0.04)]  [5c, 9c, 5s]    7h    2c        2        1
# 2                         None          None  None  None     1.94     1.06
# 3                         None          None  None  None     1.95     1.05
# 4                         None          None  None  None     1.94     1.06
# ...                        ...           ...   ...   ...      ...      ...
# 520806                    None  [Kc, 5d, 5s]  None  None     1.02     0.98
# 520807                    None          None  None  None        1        1
# 520808                    None  [9h, 6h, 7h]    Ks  None     3.36     1.90
# 520809        [(k, 0), (k, 0)]  [9d, Qc, 5d]    7d    Ac     3.42     1.84
# 520810     [(b, 0.06), (f, 0)]  [8s, Td, Tc]    4c    Jh     3.48     1.78
#
#           SB cards    BB cards  Folded pre
# 0             None        None        True
# 1       [ Qh, Tc ]  [ 6h, 2h ]       False
# 2             None        None        True
# 3             None        None        True
# 4             None        None        True
# ...            ...         ...         ...
# 520806        None        None       False
# 520807        None        None       False
# 520808        None        None       False
# 520809  [ 3d, 3s ]  [ 4h, Ah ]       False
# 520810        None        None       False
#
# [520811 rows x 16 columns]

# %%
example= df['Flop actions'][1]

# %%
example
# Out:
# [('k', 0), ('k', 0)]

# %%
type(example)
# Out:
# list

# %%
type(example[0])
# Out:
# tuple

# %%
def check_aggression(action_list):
    """
    This function looks at the actions that happened and outputs a 2 digit number
    The number represents aggression show by either player

    Player counts as aggressive if they raised or bet

    Ex:
    00 - means both passive
    10 means SB aggressive BB passive
    01 means SB passive BB aggressive
    11 means both aggressive
    """
    agg_sb=0
    agg_bb =0

    if action_list==None:
        return None
    for index,action in enumerate(action_list):
        if action[0] in ('r','b'):
            if index %2==0:
                agg_sb=1
            else:
                agg_bb=1
    return agg_sb, agg_bb

# %%
check_aggression(example)
# Out:
# (0, 0)

# %%
df['preflop aggression']=check_aggression(df['Preflop actions'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 df['preflop aggression']=check_aggression(df['Preflop actions'])
#
# File ~/miniconda3/envs/cse583/lib/python3.11/site-packages/pandas/core/frame.py:4094, in DataFrame.__setitem__(self, key, value)
#    4091     self._setitem_array([key], value)
#    4092 else:
#    4093     # set column
# -> 4094     self._set_item(key, value)
#
# File ~/miniconda3/envs/cse583/lib/python3.11/site-packages/pandas/core/frame.py:4303, in DataFrame._set_item(self, key, value)
#    4293 def _set_item(self, key, value) -> None:
#    4294     """
#    4295     Add series to DataFrame in specified column.
#    4296
#    (...)
#    4301     ensure homogeneity.
#    4302     """
# -> 4303     value, refs = self._sanitize_column(value)
#    4305     if (
#    4306         key in self.columns
#    4307         and value.ndim == 1
#    4308         and not isinstance(value.dtype, ExtensionDtype)
#    4309     ):
#    4310         # broadcast across multiple columns if necessary
#    4311         if not self.columns.is_unique or isinstance(self.columns, MultiIndex):
#
# File ~/miniconda3/envs/cse583/lib/python3.11/site-packages/pandas/core/frame.py:5042, in DataFrame._sanitize_column(self, value)
#    5039     return _reindex_for_setitem(value, self.index)
#    5041 if is_list_like(value):
# -> 5042     com.require_length_match(value, self.index)
#    5043 return sanitize_array(value, self.index, copy=True, allow_2d=True), None
#
# File ~/miniconda3/envs/cse583/lib/python3.11/site-packages/pandas/core/common.py:561, in require_length_match(data, index)
#     557 """
#     558 Check the length of data matches the length of the index.
#     559 """
#     560 if len(data) != len(index):
# --> 561     raise ValueError(
#     562         "Length of values "
#     563         f"({len(data)}) "
#     564         "does not match length of index "
#     565         f"({len(index)})"
#     566     )
#
# ValueError: Length of values (2) does not match length of index (520811)

# %%
df['Aggr preflop'] = df['Preflop actions'].apply(check_aggression)
df['Aggr flop'] = df['Flop actions'].apply(check_aggression)
df['Aggr turn'] = df['Turn actions'].apply(check_aggression)
df['Aggr river'] = df['River actions'].apply(check_aggression)

# %%
df
# Out:
#           Game ID                                               File  \
# 0       502874582  Arezzo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1       603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2       603604231  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3       603604236  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4       603604241  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...           ...                                                ...
# 520806  553224385  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520807  553224389  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520808  553224821  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520809  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520810  553224845  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB      Player BB         Preflop actions  \
# 0         Oracool1   sirstadiljus                 [(f, 0)]
# 1        ArcticWin         Ceaban      [(c, 0.01), (k, 0)]
# 2           Ceaban      ArcticWin                 [(f, 0)]
# 3        ArcticWin         Ceaban                 [(f, 0)]
# 4           Ceaban      ArcticWin                 [(f, 0)]
# ...             ...            ...                     ...
# 520806  Sensei.Dbb        roghnov      [(c, 0.01), (k, 0)]
# 520807     roghnov     Sensei.Dbb      [(r, 0.03), (f, 0)]
# 520808     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
# 520809  John_Efapi        mikvell   [(r, 0.05), (c, 0.04)]
# 520810     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
#
#                        Flop actions                 Turn actions  \
# 0                              None                         None
# 1                  [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 2                              None                         None
# 3                              None                         None
# 4                              None                         None
# ...                             ...                          ...
# 520806  [(k, 0), (b, 0.02), (f, 0)]                         None
# 520807                         None                         None
# 520808       [(b, 0.04), (c, 0.04)]  [(k, 0), (b, 0.08), (f, 0)]
# 520809             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 520810             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
#
#                  River actions          Flop  Turn  ... SB stack BB stack  \
# 0                         None          None  None  ...     1.22     2.01
# 1       [(b, 0.04), (c, 0.04)]  [5c, 9c, 5s]    7h  ...        2        1
# 2                         None          None  None  ...     1.94     1.06
# 3                         None          None  None  ...     1.95     1.05
# 4                         None          None  None  ...     1.94     1.06
# ...                        ...           ...   ...  ...      ...      ...
# 520806                    None  [Kc, 5d, 5s]  None  ...     1.02     0.98
# 520807                    None          None  None  ...        1        1
# 520808                    None  [9h, 6h, 7h]    Ks  ...     3.36     1.90
# 520809        [(k, 0), (k, 0)]  [9d, Qc, 5d]    7d  ...     3.42     1.84
# 520810     [(b, 0.06), (f, 0)]  [8s, Td, Tc]    4c  ...     3.48     1.78
#
#           SB cards    BB cards Folded pre  aggression_preflop Aggr preflop  \
# 0             None        None       True              (0, 0)       (0, 0)
# 1       [ Qh, Tc ]  [ 6h, 2h ]      False              (0, 0)       (0, 0)
# 2             None        None       True              (0, 0)       (0, 0)
# 3             None        None       True              (0, 0)       (0, 0)
# 4             None        None       True              (0, 0)       (0, 0)
# ...            ...         ...        ...                 ...          ...
# 520806        None        None      False              (0, 0)       (0, 0)
# 520807        None        None      False              (1, 0)       (1, 0)
# 520808        None        None      False              (0, 0)       (0, 0)
# 520809  [ 3d, 3s ]  [ 4h, Ah ]      False              (1, 0)       (1, 0)
# 520810        None        None      False              (0, 0)       (0, 0)
#
#        Aggr flop Aggr turn Aggr river
# 0           None      None       None
# 1         (0, 0)    (0, 0)     (1, 0)
# 2           None      None       None
# 3           None      None       None
# 4           None      None       None
# ...          ...       ...        ...
# 520806    (0, 1)      None       None
# 520807      None      None       None
# 520808    (1, 0)    (0, 1)       None
# 520809    (0, 0)    (0, 0)     (0, 0)
# 520810    (0, 0)    (0, 0)     (1, 0)
#
# [520811 rows x 21 columns]

# %%
type(df['Flop'])
# Out:
# pandas.core.series.Series
