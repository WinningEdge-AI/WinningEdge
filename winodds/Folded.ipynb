# %%
import pandas as pd

# %%
df = pd.read_pickle("../dataframe/poker_dataframe.pkl")
df
# Out:
#           Game ID                                               File  \
# 0       502874582  Arezzo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1       603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2       603604231  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3       603604236  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4       603604241  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...           ...                                                ...
# 520806  553224385  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520807  553224389  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520808  553224821  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520809  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520810  553224845  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB      Player BB         Preflop actions  \
# 0         Oracool1   sirstadiljus                 [(f, 0)]
# 1        ArcticWin         Ceaban      [(c, 0.01), (k, 0)]
# 2           Ceaban      ArcticWin                 [(f, 0)]
# 3        ArcticWin         Ceaban                 [(f, 0)]
# 4           Ceaban      ArcticWin                 [(f, 0)]
# ...             ...            ...                     ...
# 520806  Sensei.Dbb        roghnov      [(c, 0.01), (k, 0)]
# 520807     roghnov     Sensei.Dbb      [(r, 0.03), (f, 0)]
# 520808     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
# 520809  John_Efapi        mikvell   [(r, 0.05), (c, 0.04)]
# 520810     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
#
#                        Flop actions                 Turn actions  \
# 0                              None                         None
# 1                  [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 2                              None                         None
# 3                              None                         None
# 4                              None                         None
# ...                             ...                          ...
# 520806  [(k, 0), (b, 0.02), (f, 0)]                         None
# 520807                         None                         None
# 520808       [(b, 0.04), (c, 0.04)]  [(k, 0), (b, 0.08), (f, 0)]
# 520809             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 520810             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
#
#                  River actions          Flop  Turn River SB stack BB stack  \
# 0                         None          None  None  None     1.22     2.01
# 1       [(b, 0.04), (c, 0.04)]  [5c, 9c, 5s]    7h    2c        2        1
# 2                         None          None  None  None     1.94     1.06
# 3                         None          None  None  None     1.95     1.05
# 4                         None          None  None  None     1.94     1.06
# ...                        ...           ...   ...   ...      ...      ...
# 520806                    None  [Kc, 5d, 5s]  None  None     1.02     0.98
# 520807                    None          None  None  None        1        1
# 520808                    None  [9h, 6h, 7h]    Ks  None     3.36     1.90
# 520809        [(k, 0), (k, 0)]  [9d, Qc, 5d]    7d    Ac     3.42     1.84
# 520810     [(b, 0.06), (f, 0)]  [8s, Td, Tc]    4c    Jh     3.48     1.78
#
#           SB cards    BB cards  Folded pre
# 0             None        None        True
# 1       [ Qh, Tc ]  [ 6h, 2h ]       False
# 2             None        None        True
# 3             None        None        True
# 4             None        None        True
# ...            ...         ...         ...
# 520806        None        None       False
# 520807        None        None       False
# 520808        None        None       False
# 520809  [ 3d, 3s ]  [ 4h, Ah ]       False
# 520810        None        None       False
#
# [520811 rows x 16 columns]

# %%
example = df['Preflop actions'][1]
example
# Out:
# [('c', '0.01'), ('k', 0)]

# %%
def check_fold(preflop_actions, flop_actions, turn_actions, river_actions):
    
    fold_sb = False
    fold_bb = False
    
    if preflop_actions is not None:
        for index, action in enumerate(preflop_actions):
            if action[0] == 'f':
                if index % 2 == 0:
                    fold_sb = True
                else:
                    fold_bb = True
    
    if flop_actions is not None and fold_sb == False and fold_bb == False:
        for index, action in enumerate(flop_actions):
            if action[0] == 'f':
                if index % 2 == 0:
                    fold_sb = True
                else:
                    fold_bb = True
    
    if turn_actions is not None and fold_sb == False and fold_bb == False:
        for index, action in enumerate(turn_actions):
            if action[0] == 'f':
                if index % 2 == 0:
                    fold_sb = True
                else:
                    fold_bb = True
    
    if river_actions is not None and fold_sb == False and fold_bb == False:
        for index, action in enumerate(river_actions):
            if action[0] == 'f':
                if index % 2 == 0:
                    fold_sb = True
                else:
                    fold_bb = True
    
    return fold_sb, fold_bb

# %%
preflop_ex = df['Preflop actions'][1]
flop_ex = df['Flop actions'][1]
turn_ex = df['Turn actions'][1]
river_ex = df['River actions'][1]

# %%
check_fold(preflop_ex, flop_ex, turn_ex, river_ex)
# Out:
# (False, False)

# %%
df['fold_sb'], df['fold_bb'] = zip(*df.apply(lambda row: check_fold(row['Preflop actions'], row['Flop actions'], row['Turn actions'], row['River actions']), axis=1))

# %%
df
# Out:
#           Game ID                                               File  \
# 0       502874582  Arezzo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1       603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2       603604231  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3       603604236  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4       603604241  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...           ...                                                ...
# 520806  553224385  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520807  553224389  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520808  553224821  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520809  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520810  553224845  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB      Player BB         Preflop actions  \
# 0         Oracool1   sirstadiljus                 [(f, 0)]
# 1        ArcticWin         Ceaban      [(c, 0.01), (k, 0)]
# 2           Ceaban      ArcticWin                 [(f, 0)]
# 3        ArcticWin         Ceaban                 [(f, 0)]
# 4           Ceaban      ArcticWin                 [(f, 0)]
# ...             ...            ...                     ...
# 520806  Sensei.Dbb        roghnov      [(c, 0.01), (k, 0)]
# 520807     roghnov     Sensei.Dbb      [(r, 0.03), (f, 0)]
# 520808     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
# 520809  John_Efapi        mikvell   [(r, 0.05), (c, 0.04)]
# 520810     mikvell     John_Efapi      [(c, 0.01), (k, 0)]
#
#                        Flop actions                 Turn actions  \
# 0                              None                         None
# 1                  [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 2                              None                         None
# 3                              None                         None
# 4                              None                         None
# ...                             ...                          ...
# 520806  [(k, 0), (b, 0.02), (f, 0)]                         None
# 520807                         None                         None
# 520808       [(b, 0.04), (c, 0.04)]  [(k, 0), (b, 0.08), (f, 0)]
# 520809             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
# 520810             [(k, 0), (k, 0)]             [(k, 0), (k, 0)]
#
#                  River actions          Flop  Turn River SB stack BB stack  \
# 0                         None          None  None  None     1.22     2.01
# 1       [(b, 0.04), (c, 0.04)]  [5c, 9c, 5s]    7h    2c        2        1
# 2                         None          None  None  None     1.94     1.06
# 3                         None          None  None  None     1.95     1.05
# 4                         None          None  None  None     1.94     1.06
# ...                        ...           ...   ...   ...      ...      ...
# 520806                    None  [Kc, 5d, 5s]  None  None     1.02     0.98
# 520807                    None          None  None  None        1        1
# 520808                    None  [9h, 6h, 7h]    Ks  None     3.36     1.90
# 520809        [(k, 0), (k, 0)]  [9d, Qc, 5d]    7d    Ac     3.42     1.84
# 520810     [(b, 0.06), (f, 0)]  [8s, Td, Tc]    4c    Jh     3.48     1.78
#
#           SB cards    BB cards  Folded pre  fold_sb  fold_bb
# 0             None        None        True     True    False
# 1       [ Qh, Tc ]  [ 6h, 2h ]       False    False    False
# 2             None        None        True     True    False
# 3             None        None        True     True    False
# 4             None        None        True     True    False
# ...            ...         ...         ...      ...      ...
# 520806        None        None       False     True    False
# 520807        None        None       False    False     True
# 520808        None        None       False     True    False
# 520809  [ 3d, 3s ]  [ 4h, Ah ]       False    False    False
# 520810        None        None       False    False     True
#
# [520811 rows x 18 columns]
