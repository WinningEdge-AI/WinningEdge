# %%
import ast
from collections import Counter
import os

import numpy as np
import pandas as pd
import warnings

from winedge import Card, Evaluator
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Ubuntu\home\jtatka\WinningEdge\winedge\straight_flush.ipynb Cell 1 line 9
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W1sZmlsZQ%3D%3D?line=5'>6</a> import pandas as pd
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W1sZmlsZQ%3D%3D?line=6'>7</a> import warnings
# ----> <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W1sZmlsZQ%3D%3D?line=8'>9</a> from winedge import Card, Evaluator
#
# ModuleNotFoundError: No module named 'winedge'

# %%
df = pd.read_pickle('/home/jtatka/WinningEdge/dataframe/poker_dataframe.pkl')
st_df = df

#Add Columns to dataframe for SB & BB Handrank and Handstrength
warnings.filterwarnings('ignore')
st_df['Flop Flush Risk'] = np.nan
st_df['Flop Straight Risk'] = np.nan
st_df['Turn Flush Risk'] = np.nan
st_df['Turn Straight Risk'] = np.nan
st_df['River Flush Risk'] = np.nan
st_df['River Straight Risk'] = np.nan
st_df
# Out:
#           Game ID                                               File  \
# 0       502874582  Arezzo-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 1       603604223  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 2       603604231  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 3       603604236  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# 4       603604241  Asmara-0.01-0.02-USD-NoLimitHoldem-Pacific-6-4...
# ...           ...                                                ...
# 520806  553224385  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520807  553224389  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520808  553224821  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520809  553224834  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
# 520810  553224845  Corrientes-0.01-0.02-USD-NoLimitHoldem-Pacific...
#
#           Player SB      Player BB         Preflop actions  \
# 0         Oracool1   sirstadiljus                 [(f, 0)]
# ...

# %%
# evaluate for flop
suit_list = ['c','h','s','d']
counts= Counter(suit_char_list)

suit_char = [card[1] for card in st_df['Flop'][1]]
if any(count == 3 for )
# Out:
# ['c', 'c', 's']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Ubuntu\home\jtatka\WinningEdge\winedge\straight_flush.ipynb Cell 3 line 1
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W3sZmlsZQ%3D%3D?line=6'>7</a> suit_char = [card[1] for card in st_df['Flop'][1]]
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W3sZmlsZQ%3D%3D?line=7'>8</a> print(suit_char)
# ---> <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W3sZmlsZQ%3D%3D?line=9'>10</a> suit_char = st_df['Flop'].apply(lambda x: x[1])
#      <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#W3sZmlsZQ%3D%3D?line=10'>11</a> print(list(suit_char))
#
# ...

# %%
# eval straights

# def int_to_str(card_int):
#         """
#         Convert integer ranks to strings so human like us can comprehend
#         """
#         rank_int = Card.get_rank_int(card_int)
#         suit_int = Card.get_suit_int(card_int)
#         return Card.STR_RANKS[rank_int] + Card.INT_SUIT_

rank_char = [card[0] for card in st_df['Flop'][1]]
int_rank = [Card.get_rank_int(rank_char[card]) for card in rank_char]
print(int_rank)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Ubuntu\home\jtatka\WinningEdge\winedge\straight_flush.ipynb Cell 4 line 1
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> # eval straights
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a>
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> # def int_to_str(card_int):
#    (...)
#       <a href='vscode-notebook-cell://wsl.localhost/Ubuntu/home/jtatka/WinningEdge/winedge/straight_flush.ipynb#X13sZmlsZQ%3D%3D?line=7'>8</a> #         suit_int = Card.get_suit_int(card_int)
# ...
